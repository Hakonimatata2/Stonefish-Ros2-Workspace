# %% [markdown]
# ## This noetebook is for inspecting topics and data of a bag file

# %%
from rosbags.highlevel import AnyReader
from pathlib import Path
from tools.bag_to_df import bag_topic_to_dataframe
from tools.tools import *
import matplotlib.pyplot as plt 

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bagdir = '/root/stonefish_ros2_ws/sintef_dataset/2024-08-22_14-29-05_data.bag'

print_bag_topics(bagdir)
# Out:
# Topics and message types:
# /bluerov2/alive                                std_msgs/msg/Float32
# /bluerov2/armed                                std_msgs/msg/Float32
# /bluerov2/battery                              messages/msg/BatteryStatus
# /bluerov2/modes                                joystick/msg/ModeManager2
# /commanded_thrust                              rospy_tutorials/msg/Floats
# /controller/x                                  messages/msg/MRACOupdate
# /controller/y                                  messages/msg/MRACOupdate
# /controller/yaw                                messages/msg/PIDState
# /controller/z                                  messages/msg/PIDState
# /gui/netFollowing_manager                      messages/msg/NetFollowingManager
# /guidance                                      messages/msg/GuidanceManager
# /joystick                                      joystick/msg/Joystick
# /joystick/dvl_reset_position                   messages/msg/BoolStamped
# /joystick/init                                 std_msgs/msg/Float32
# /navigation/plane_approximation                messages/msg/PlaneApproximation
# /navigation/plane_approximation_position       messages/msg/PlaneApproximationPosition
# /nucleus1000dvl/altimeter                      sensors/msg/Nucleus1000_altimeter
# /nucleus1000dvl/bottomtrack                    sensors/msg/Nucleus1000_bottomtrack
# /nucleus1000dvl/imu                            sensors/msg/Nucleus1000_imu
# /nucleus1000dvl/ins                            sensors/msg/Nucleus1000_ins
# /nucleus1000dvl/magnetometer                   sensors/msg/Nucleus1000_magnetometer
# /nucleus1000dvl/watertrack                     sensors/msg/Nucleus1000_watertrack
# /rosout                                        rosgraph_msgs/msg/Log
# /rosout                                        rosgraph_msgs/msg/Log
# /rosout                                        rosgraph_msgs/msg/Log
# /rosout                                        rosgraph_msgs/msg/Log
# /sensor/attitude                               messages/msg/Attitude
# /sensor/depth_temperature                      messages/msg/DepthTemperature
# /sensor/dvl_position                           sensors/msg/DVLPosition
# /sensor/dvl_velocity                           sensors/msg/DVLVelocity
# /sensor/imu                                    messages/msg/IMU
# /sensor/ping360_config                         sensors/msg/Ping360_config_2
# /sensor/usbl                                   sensors/msg/SonardyneUSBL2

# %%
data = bag_topic_to_dataframe(bag_path=bagdir, topic="/nucleus1000dvl/ins")
data.head()
# Out:
# /root/stonefish_ros2_ws/plots/tools/bag_to_df.py:212: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[c] = pd.to_numeric(df[c], errors='ignore')
#               t                  __msgtype__  altitude  courseOverGround  \
# 0  1.724330e+09  sensors/msg/Nucleus1000_ins      -1.0         80.266678
# 1  1.724330e+09  sensors/msg/Nucleus1000_ins      -1.0         81.819534
# 2  1.724330e+09  sensors/msg/Nucleus1000_ins      -1.0         92.968010
# 3  1.724330e+09  sensors/msg/Nucleus1000_ins      -1.0         94.181534
# 4  1.724330e+09  sensors/msg/Nucleus1000_ins      -1.0         95.378746
#
#    declination     depth   fomAhrs  fomFc1    fomIns   header.__msgtype__  \
# 0          0.0  2.207257  0.509452     0.0  2.803900  std_msgs/msg/Header
# 1          0.0  2.207257  0.508753     0.0  2.804440  std_msgs/msg/Header
# 2          0.0  2.188357  0.507641     0.0  2.804978  std_msgs/msg/Header
# 3          0.0  2.188357  0.504891     0.0  2.805515  std_msgs/msg/Header
# 4          0.0  2.188357  0.502182     0.0  2.806051  std_msgs/msg/Header
#
#    ...  turnRate.y  turnRate.z    velocityNed.__msgtype__  velocityNed.x  \
# 0  ...  -14.939211   -3.135995  geometry_msgs/msg/Vector3       0.018611
# 1  ...  -15.591107   -3.171875  geometry_msgs/msg/Vector3       0.015666
# 2  ...  -14.657893   -3.760612  geometry_msgs/msg/Vector3      -0.003592
# 3  ...  -13.548294   -2.528120  geometry_msgs/msg/Vector3      -0.005103
# 4  ...  -12.119763   -1.968699  geometry_msgs/msg/Vector3      -0.006604
#
#    velocityNed.y  velocityNed.z  velocityNucleus.__msgtype__  \
# 0       0.108499      -0.002420    geometry_msgs/msg/Vector3
# 1       0.108979      -0.001591    geometry_msgs/msg/Vector3
# 2       0.069272      -0.067096    geometry_msgs/msg/Vector3
# 3       0.069792      -0.066456    geometry_msgs/msg/Vector3
# 4       0.070142      -0.065954    geometry_msgs/msg/Vector3
#
#    velocityNucleus.x  velocityNucleus.y velocityNucleus.z
# 0           0.046500           0.000075          0.099810
# 1           0.046500           0.000075          0.099810
# 2           0.019163           0.066941          0.066821
# 3           0.019163           0.066941          0.066821
# 4           0.019163           0.066941          0.066821
#
# [5 rows x 43 columns]

# %%
data = bag_topic_to_dataframe(bag_path=bagdir, topic="/nucleus1000dvl/bottomtrack")
data.head()
# Out:
# /root/stonefish_ros2_ws/plots/tools/bag_to_df.py:212: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[c] = pd.to_numeric(df[c], errors='ignore')
#               t                          __msgtype__  data_valid  \
# 0  1.724330e+09  sensors/msg/Nucleus1000_bottomtrack        True
# 1  1.724330e+09  sensors/msg/Nucleus1000_bottomtrack        True
# 2  1.724330e+09  sensors/msg/Nucleus1000_bottomtrack        True
# 3  1.724330e+09  sensors/msg/Nucleus1000_bottomtrack        True
# 4  1.724330e+09  sensors/msg/Nucleus1000_bottomtrack        True
#
#      dvl_fom_xyz.__msgtype__  dvl_fom_xyz.x  dvl_fom_xyz.y  dvl_fom_xyz.z  \
# 0  geometry_msgs/msg/Vector3       0.000296       0.000298       0.000076
# 1  geometry_msgs/msg/Vector3       0.000296       0.000298       0.000076
# 2  geometry_msgs/msg/Vector3       0.000305       0.000324       0.000080
# 3  geometry_msgs/msg/Vector3       0.000384       0.000311       0.000089
# 4  geometry_msgs/msg/Vector3       0.000804       0.001339       0.000283
#
#    dvl_time_velocity_estimate_xyz  dvl_velocity_dt_xyz  \
# 0                             0.0             0.006812
# 1                             0.0             0.006767
# 2                             0.0             0.006955
# 3                             0.0             0.006849
# 4                             0.0             0.006767
#
#   dvl_velocity_xyz.__msgtype__  ...   header.__msgtype__  header.frame_id  \
# 0    geometry_msgs/msg/Vector3  ...  std_msgs/msg/Header              NaN
# 1    geometry_msgs/msg/Vector3  ...  std_msgs/msg/Header              NaN
# 2    geometry_msgs/msg/Vector3  ...  std_msgs/msg/Header              NaN
# 3    geometry_msgs/msg/Vector3  ...  std_msgs/msg/Header              NaN
# 4    geometry_msgs/msg/Vector3  ...  std_msgs/msg/Header              NaN
#
#    header.seq     header.stamp.__msgtype__ header.stamp.nanosec  \
# 0          72  builtin_interfaces/msg/Time            266978025
# 1          73  builtin_interfaces/msg/Time            722280502
# 2          74  builtin_interfaces/msg/Time            150550842
# 3          75  builtin_interfaces/msg/Time            112363815
# 4          76  builtin_interfaces/msg/Time            566138267
#
#    header.stamp.sec  pressure sound_speed  status  temperature
# 0        1724329752    0.2219      1500.0       0    15.609375
# 1        1724329752    0.2219      1500.0       0    15.601562
# 2        1724329753    0.2219      1500.0       0    15.601562
# 3        1724329754    0.2228      1500.0       0    15.609375
# 4        1724329754    0.2237      1500.0       0    15.601562
#
# [5 rows x 24 columns]

# %% [markdown]
# # Inspect images

# %%
video_bagdir = "/root/stonefish_ros2_ws/sintef_dataset/2024-08-22_14-29-05_video.bag"
print_bag_topics(video_bagdir)
camera = get_compressed_color_image(bag=video_bagdir, topic="/image/compressed_image/data")
# Out:
# Topics and message types:
# /image/compressed_image/camera_info            sensor_msgs/msg/CameraInfo
# /image/compressed_image/data                   sensor_msgs/msg/CompressedImage
# /sensor/sonoptix_echo/image                    sensors/msg/SonoptixECHO

# %%
img = get_image_nearest_time(camera, target_time=10)
print(img.shape)
plt.imshow(img)

dt = camera["time"][20] - camera["time"][19]
print(f"frequency: {1/dt:.2f}")
# Out:
# (720, 1280, 3)
# frequency: 30.08

# %%
sonar_data = get_sonoptix_data(video_bagdir, "/sensor/sonoptix_echo/image")

# %%
image = get_image_nearest_time(sonar_data, 10)

# Clip
image = image[:400, :]

# Map to polar
image = map_to_sector(image, fov_deg=120)

# Normalize intenisty values 0 to 255
image = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX)

# Log transform
# image = np.log(image + 1)

# Flip
image = np.flipud(image) 

plt.figure(figsize=(10, 10))
plt.title("Sonoptix ECHO")
plt.imshow(image, cmap="hot")
